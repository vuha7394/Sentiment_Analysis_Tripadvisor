# %%
# !pip install torch
# !pip install transformers
# !pip3 install tokenizers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install tensorflow
# !pip install tensorflow-text
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from transformers import AutoModelForSequenceClassification, RobertaForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
from scipy.special import softmax
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "gpu")

# %%
model = RobertaForSequenceClassification.from_pretrained("wonrax/phobert-base-vietnamese-sentiment")
model.to(device)
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(64001, 768, padding_idx=1)
#       (position_embeddings): Embedding(258, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
# ...

# %%
tokenizer = AutoTokenizer.from_pretrained("wonrax/phobert-base-vietnamese-sentiment", use_fast=False)

# %%
# !pip install underthesea
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#from underthesea import word_tokenize

# %%
# INPUT TEXT MUST BE ALREADY WORD-SEGMENTED!
#sentence = 'Khách sạn mới, rộng và đẹp. Nhân viên phục vụ chu đáo.'
#sentence_seg = word_tokenize(sentence, format="text")
#sentence_seg

# %%
#input_ids = torch.tensor([tokenizer.encode(sentence_seg)]).to(device)

# %%
#with torch.no_grad():
#  out = model(input_ids)
#  print(out.logits.softmax(dim=-1).tolist()) # NEG POS NEU

# %% [markdown]
# PHOBERT

# %%
import torch
from transformers import AutoModel, AutoTokenizer

phobert = AutoModel.from_pretrained("vinai/phobert-base")
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")

# INPUT TEXT MUST BE ALREADY WORD-SEGMENTED!
#sentence = 'Chúng_tôi là những nghiên_cứu_viên .'  

#input_ids = torch.tensor([tokenizer.encode(sentence)])

#with torch.no_grad():
#    features = phobert(input_ids)  # Models outputs are now tuples

## With TensorFlow 2.0+:
# from transformers import TFAutoModel
# phobert = TFAutoModel.from_pretrained("vinai/phobert-base")
# Out:
# Some weights of the model checkpoint at vinai/phobert-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# !pip install py_vncorenlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)

# %%
# %cd '/content/gdrive/My Drive/MDS0_k278_VuThiHa/Cau_3/'

# %%
df = pd.read_csv('process_data.csv', index_col=0)

# %%
df.head()
# Out:
#                                                 text  rating sentiment  \
# 0  Quá Tuyệt Vời Khi Ở Des Arts Sài Gòn. #HôtelDe...       5  Positive
# 1  Đáng đồng tiền!. Dịch vụ cao cấp, phong cách c...       5  Positive
# 2  huyền bí và ấn tượng. vài dòng note lại về #Mg...       5  Positive
# 3  love decor and service. Mình rất thích ngắm má...       5  Positive
# 4  Dễ thương, ấm cúng. Ks không lớn lắm nhưng có ...       4  Positive
#
#    output                                     processed_text
# 0       1  tuyệt_vời trải_nghiệm tuyệt_vời ghé tươi thích...
# 1       1  đồng_tiền chuyên_nghiệp hơi thích_hợp chống tr...
# 2       1  chú_ý lướt đắm chìm bình_yên thoải_mái thân_th...
# 3       1  thích ngắm tròn thư_thái lắm thượng bơi nối ng...
# 4       1  không_lớn lắm trí thân_thiện đẹp ngắm giá_cả n...

# %%
data=df[['processed_text','output']]

# %%
data.head()
# Out:
#                                       processed_text  output
# 0  tuyệt_vời trải_nghiệm tuyệt_vời ghé tươi thích...       1
# 1  đồng_tiền chuyên_nghiệp hơi thích_hợp chống tr...       1
# 2  chú_ý lướt đắm chìm bình_yên thoải_mái thân_th...       1
# 3  thích ngắm tròn thư_thái lắm thượng bơi nối ng...       1
# 4  không_lớn lắm trí thân_thiện đẹp ngắm giá_cả n...       1

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import confusion_matrix

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text

# %%
bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
bert_encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4")

# %%
# split data
X_train, X_test, y_train, y_test = train_test_split(data['processed_text'], data['output'], stratify=data['output'], test_size=0.3)
X_train.head(4)
# Out:
# 74528    nghỉ vắng trải_nghiệm độc_đáo tour đắm_mình mê...
# 80702     vọng thích kỳ_lạ cũ cắn trở_nên tốt thuê đạp tốt
# 77497                đẹp ổn tốt tốt tiết_kiệm để_dành tiếp
# 1339              tốt toàn mặc_dù độc_thân thích tuyệt_vời
# Name: processed_text, dtype: object

# %%
data['processed_text'].head()
# Out:
# 0    tuyệt_vời trải_nghiệm tuyệt_vời ghé tươi thích...
# 1    đồng_tiền chuyên_nghiệp hơi thích_hợp chống tr...
# 2    chú_ý lướt đắm chìm bình_yên thoải_mái thân_th...
# 3    thích ngắm tròn thư_thái lắm thượng bơi nối ng...
# 4    không_lớn lắm trí thân_thiện đẹp ngắm giá_cả n...
# Name: processed_text, dtype: object

# %%
data['output'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: output, dtype: int64

# %%
X_train=X_train.to_list()
y_train=y_train.to_list()
X_test=X_test.to_list()
y_test=y_test.to_list()

# %%
import tensorflow as tf
import tensorflow_hub as hub
#!pip install tensorflow-text
import tensorflow_text as text

# %%
# Bert layers
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
preprocessed_text = bert_preprocess(text_input)
outputs = bert_encoder(preprocessed_text)

# %%
# Neural network layers
l = tf.keras.layers.Dropout(0.1, name="dropout")(outputs['pooled_output'])
l = tf.keras.layers.Dense(1, activation='sigmoid', name="output")(l)
# Use inputs and outputs to construct a final model
model = tf.keras.Model(inputs=[text_input], outputs = [l])

# %%
import datetime
t0 = datetime.datetime.now()
print(t0)
# Out:
# 2022-09-22 15:21:05.768707

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history=model.fit(X_train, y_train, epochs=30, batch_size = 32)
# Out:
# Epoch 1/30
# 1803/1803 [==============================] - 604s 326ms/step - loss: 0.4246 - accuracy: 0.8452
# Epoch 2/30
# 1803/1803 [==============================] - 592s 328ms/step - loss: 0.4102 - accuracy: 0.8461
# Epoch 3/30
# 1803/1803 [==============================] - 591s 328ms/step - loss: 0.4026 - accuracy: 0.8465
# Epoch 4/30
# 1803/1803 [==============================] - 591s 328ms/step - loss: 0.3987 - accuracy: 0.8466
# Epoch 5/30
# 1803/1803 [==============================] - 591s 328ms/step - loss: 0.3961 - accuracy: 0.8463
# Epoch 6/30
# 1803/1803 [==============================] - 589s 327ms/step - loss: 0.3954 - accuracy: 0.8469
# Epoch 7/30
# 1803/1803 [==============================] - 588s 326ms/step - loss: 0.3943 - accuracy: 0.8469
# Epoch 8/30
# 1803/1803 [==============================] - 589s 326ms/step - loss: 0.3927 - accuracy: 0.8464
# Epoch 9/30
# 1803/1803 [==============================] - 588s 326ms/step - loss: 0.3939 - accuracy: 0.8470
# ...

# %%
t1 = datetime.datetime.now()
print(t1-t0)
# Out:
# 5:09:01.610719

# %%
y_predicted = model.predict(X_test)
y_predicted = y_predicted.flatten()
print(y_predicted)
# Out:
# 773/773 [==============================] - 249s 322ms/step
# [0.8763795  0.8717124  0.89490473 ... 0.92638636 0.8971026  0.9439176 ]

# %%
model.save('Topic_02_BERT.h5')

# %%
##test accuracy 
accr = model.evaluate(X_test, y_test)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0], accr[1]))
# Out:
# 773/773 [==============================] - 253s 326ms/step - loss: 0.3935 - accuracy: 0.8457
# Test set
#   Loss: 0.394
#   Accuracy: 0.846

# %%
#y_pred = model.predict(X_test)
#y_pred
